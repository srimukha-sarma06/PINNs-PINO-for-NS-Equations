# %%
import os
os.environ["DDE_BACKEND"] = "tensorflow"

# %%
import deepxde as dde
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
geom = dde.geometry.Disk(center=(0.0, 0.0), radius=1)
axial = dde.geometry.
