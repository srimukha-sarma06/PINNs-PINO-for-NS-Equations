# %%
import pandas as pd
data = pd.read_csv('Flow.csv')

# %%
data.head()
# Out:
#           t         x         y         u         v         p      dudx  \
# 0  0.022222  0.368421  0.088889  0.393358  0.001115 -2.953893  0.152946
# 1  0.100000  0.315789  0.077778  0.694818 -0.001654 -2.531341 -0.100485
# 2  0.033333  0.263158  0.022222  0.704109 -0.000018 -2.103342  0.178065
# 3  0.100000  0.052632  0.044444  1.002908 -0.001317 -0.410112 -0.151426
# 4  0.011111  0.789474  0.100000 -0.010775 -0.002226 -6.315435  0.000000
#
#         dudy      dvdx      dvdy      dudt      dvdt flow_type  sample_id
# 0 -31.138013  0.030149 -0.082668 -0.820783  0.018075   laminar         63
# 1 -21.879110 -0.007235  0.056004 -0.027166 -0.151602   laminar         77
# 2  23.040452  0.022634  0.011209  0.343724 -0.002956   laminar         67
# 3   4.189388 -0.037293 -0.000843  1.339783 -0.056770   laminar         52
# 4   0.000000  0.000000  0.000000  0.179054  0.061017   laminar         62

# %%
len(data)
# Out:
# 10000

# %%
data["flow_type"].unique()
# Out:
# <StringArray>
# ['laminar', 'turbulent']
# Length: 2, dtype: str

# %%
data_laminar = data[data["flow_type"] == "laminar"]

# %%
len(data_laminar)
# Out:
# 5000

# %%
data_turbulent = data[data['flow_type'] == "turbulent"]
data_turbulent.head()
# Out:
#              t         x         y         u         v         p      dudx  \
# 5000  0.100000  0.789474  0.088889  1.026712  0.397843 -0.591745  3.612397
# 5001  0.044444  0.315789  0.077778  0.556785  0.064779 -0.141264 -4.962022
# 5002  0.100000  0.684211  0.022222  0.902449  0.001249 -0.474272  2.077224
# 5003  0.088889  0.473684  0.044444  0.846398 -0.070730 -0.399574  2.375436
# 5004  0.100000  0.368421  0.100000 -0.119631 -0.240132 -0.031333  0.000000
#
#            dudy      dvdx      dvdy      dudt      dvdt  flow_type  sample_id
# 5000 -16.325661  2.214610 -0.576598  4.703211  1.143310  turbulent        160
# 5001 -16.182555 -3.764561  2.288760  7.204553  7.237551  turbulent        172
# 5002  -1.788085  3.266051  0.896039 -8.693098 -2.820684  turbulent        166
# 5003   1.094349 -0.982396  2.121602  2.310548  0.393388  turbulent        151
# 5004   0.000000  0.000000  0.000000  6.129408 -6.712281  turbulent        159

# %%
data_laminar.to_csv("Laminar_dataset.csv")

# %%
data_turbulent.to_csv("Turbulent_dataset.csv")

# %%
data_laminar.head()
# Out:
#           t         x         y         u         v         p      dudx  \
# 0  0.022222  0.368421  0.088889  0.393358  0.001115 -2.953893  0.152946
# 1  0.100000  0.315789  0.077778  0.694818 -0.001654 -2.531341 -0.100485
# 2  0.033333  0.263158  0.022222  0.704109 -0.000018 -2.103342  0.178065
# 3  0.100000  0.052632  0.044444  1.002908 -0.001317 -0.410112 -0.151426
# 4  0.011111  0.789474  0.100000 -0.010775 -0.002226 -6.315435  0.000000
#
#         dudy      dvdx      dvdy      dudt      dvdt flow_type  sample_id
# 0 -31.138013  0.030149 -0.082668 -0.820783  0.018075   laminar         63
# 1 -21.879110 -0.007235  0.056004 -0.027166 -0.151602   laminar         77
# 2  23.040452  0.022634  0.011209  0.343724 -0.002956   laminar         67
# 3   4.189388 -0.037293 -0.000843  1.339783 -0.056770   laminar         52
# 4   0.000000  0.000000  0.000000  0.179054  0.061017   laminar         62

# %%
data_laminar["x"].unique(), data_laminar["y"].unique()
# Out:
# (array([0.36842105, 0.31578947, 0.26315789, 0.05263158, 0.78947368,
#         0.73684211, 0.        , 0.89473684, 0.52631579, 0.47368421,
#         0.21052632, 0.63157895, 0.94736842, 0.68421053, 0.10526316,
#         0.42105263, 0.15789474, 0.57894737, 1.        , 0.84210526]),
#  array([0.08888889, 0.07777778, 0.02222222, 0.04444444, 0.1       ,
#         0.06666667, 0.03333333, 0.05555556, 0.        , 0.01111111]))

# %%
data_laminar = data_laminar.drop(["flow_type", "sample_id"], axis=1)

# %%
data_laminar.head()
# Out:
#           t         x         y         u         v         p      dudx  \
# 0  0.022222  0.368421  0.088889  0.393358  0.001115 -2.953893  0.152946
# 1  0.100000  0.315789  0.077778  0.694818 -0.001654 -2.531341 -0.100485
# 2  0.033333  0.263158  0.022222  0.704109 -0.000018 -2.103342  0.178065
# 3  0.100000  0.052632  0.044444  1.002908 -0.001317 -0.410112 -0.151426
# 4  0.011111  0.789474  0.100000 -0.010775 -0.002226 -6.315435  0.000000
#
#         dudy      dvdx      dvdy      dudt      dvdt
# 0 -31.138013  0.030149 -0.082668 -0.820783  0.018075
# 1 -21.879110 -0.007235  0.056004 -0.027166 -0.151602
# 2  23.040452  0.022634  0.011209  0.343724 -0.002956
# 3   4.189388 -0.037293 -0.000843  1.339783 -0.056770
# 4   0.000000  0.000000  0.000000  0.179054  0.061017

# %%
data_laminar.to_csv("Laminar_dataset.csv")

# %%
data_turbulent = data_turbulent.drop(["flow_type", "sample_id"], axis=1)
data_turbulent.to_csv("Turbulent_dataset.csv")

# %%
data_laminar.describe()
# Out:
#                  t            x            y            u            v  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.050573     0.496547     0.050364     0.600999     0.000024
# std       0.031246     0.302907     0.031581     0.346460     0.001376
# min       0.000000     0.000000     0.000000    -0.032690    -0.005760
# 25%       0.022222     0.210526     0.022222     0.392070    -0.000890
# 50%       0.055556     0.526316     0.055556     0.691358    -0.000011
# 75%       0.077778     0.736842     0.077778     0.894105     0.000953
# max       0.100000     1.000000     0.100000     1.018075     0.006097
#
#                  p         dudx         dudy         dvdx         dvdy  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     -3.665240     0.000185    -0.114731     0.000172    -0.001845
# std       2.551494     0.108610    17.924191     0.015960     0.075724
# ...

# %%
print(data_laminar["x"] == 0.0)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: x, Length: 5000, dtype: bool
